# %%
import requests as rq
import pandas as pd 
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Edge()

# %%
source='CMN'
destination='PAR'
date='2023-12-04'
kayak=f"https://www.kayak.ae/flights/{source}-{destination}/{date}?sort=bestflight_a"
driver.get(kayak)
soup = BeautifulSoup(driver.page_source, 'html.parser')
#result = rq.get(kayak)
# get page content 

#src=result.content
 

# create soup object to parse content 

#soup = BeautifulSoup(src,"html.parser")
soup
# Out:
# <html class="Flights-Search-FlightSearchPage-Html" lang="en-ae"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
# <link data-type="page" href="https://content.r9cdn.net/res/combined.css?v=7229fe9a480f727213c2c9ed7ba07c01953f769e-14pre-flipped&amp;cluster=5" rel="stylesheet"/>
# <link data-type="page" href="https://content.r9cdn.net/res/combined.css?v=c3a1c7821acea6f9c95ea2cc301e219f69afe3a3-14pre-flipped&amp;cluster=5" rel="stylesheet"/>
# <link data-type="page" href="https://content.r9cdn.net/res/css/stl.css?v=bf4fd760016dcf665a4b3947682f1a3ccfbbfe26-14pre-flipped-nc&amp;cluster=5" rel="stylesheet"/>
# <style data-type="style-metadata2" type="application/metadata2">
# 60Bg1B75g3C24E21E23C2UUB5CC1C11E2CC9Bg69E8Cg1w13Q313I81C37ED;...</style>
# <style type="text/css">svg use { pointer-events: none; }</style>
# <meta content="width=980" name="viewport"/>
# <link href="/favicon.ico" rel="icon" sizes="any"/>
# <link href="/icon.svg" rel="icon" type="image/svg+xml"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="" name="seop"/>
# <meta content="" name="tags"/>
# <meta content="R694c" name="r9-version"/>
# <meta content="20231122.103213" name="r9-built"/>
# <meta content="20231122.191046.EST" name="r9-rendered"/>
# <meta content="false" name="seo-cache"/>
# <meta content="F474AA342B64B17CDE53F5C5D4C07C7A" name="msvalidate.01"/>
# <meta content="https://content.r9cdn.net/rimg/dimg/bd/d1/2f268866-city-36014-162f82486f9.jpg?width=1200&amp;height=630&amp;crop=true&amp;xhint=2562&amp;yhint=1479" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="CMN to PAR, 4/12" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="KAYAK searches hundreds of other travel sites at once to get you the information you need to make the right decisions." property="og:description"/>
# <meta content="https://www.kayak.ae/flights/CMN-PAR/2023-12-04" property="og:url"/>
# <meta content="KAYAK" property="og:site_name"/>
# <meta content="90811893045" property="fb:pages"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@KAYAK" name="twitter:site"/>
# <meta content="@KAYAK" name="twitter:creator"/>
# <meta content="CMN to PAR, 4/12" name="twitter:title"/>
# <meta content="KAYAK searches hundreds of other travel sites at once to get you the information you need to make the right decisions." name="twitter:description"/>
# <meta content="https://content.r9cdn.net/rimg/dimg/bd/d1/2f268866-city-36014-162f82486f9.jpg?width=440&amp;height=220&amp;crop=true&amp;xhint=2562&amp;yhint=1479" name="twitter:image:src"/>
# <meta content="flight,results,unknown" name="kayak_page"/>
# <meta content="noindex,nofollow,noodp" name="robots"/>
# <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
# <link href="/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/apple-touch-icon-167x167.png" rel="apple-touch-icon" sizes="167x167"/>
# <link href="/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://www.kayak.ae/flights/CMN-PAR/2023-12-04" hreflang="en-AE" rel="alternate"/>
# <link href="https://www.kayak.com.ar/flights/CMN-PAR/2023-12-04" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.at.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="de-AT" rel="alternate"/>
# <link href="https://www.kayak.com.au/flights/CMN-PAR/2023-12-04" hreflang="en-AU" rel="alternate"/>
# <link href="https://www.be.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="nl-BE" rel="alternate"/>
# <link href="https://www.kayak.com.br/flights/CMN-PAR/2023-12-04" hreflang="pt-BR" rel="alternate"/>
# <link href="https://www.ca.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="en-CA" rel="alternate"/>
# <link href="https://www.kayak.ch/flights/CMN-PAR/2023-12-04" hreflang="de-CH" rel="alternate"/>
# <link href="https://www.kayak.cl/flights/CMN-PAR/2023-12-04" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.cn.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="zh-CN" rel="alternate"/>
# <link href="https://www.kayak.com.co/flights/CMN-PAR/2023-12-04" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.cz.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="cs-CZ" rel="alternate"/>
# <link href="https://www.kayak.de/flights/CMN-PAR/2023-12-04" hreflang="de-DE" rel="alternate"/>
# <link href="https://www.kayak.dk/flights/CMN-PAR/2023-12-04" hreflang="da-DK" rel="alternate"/>
# <link href="https://www.kayak.es/flights/CMN-PAR/2023-12-04" hreflang="es-ES" rel="alternate"/>
# <link href="https://www.fi.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="fi-FI" rel="alternate"/>
# <link href="https://www.kayak.fr/flights/CMN-PAR/2023-12-04" hreflang="fr-FR" rel="alternate"/>
# <link href="https://www.kayak.co.uk/flights/CMN-PAR/2023-12-04" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.gr.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="el-GR" rel="alternate"/>
# <link href="https://www.kayak.com.hk/flights/CMN-PAR/2023-12-04" hreflang="zh-HK" rel="alternate"/>
# <link href="https://www.kayak.co.id/flights/CMN-PAR/2023-12-04" hreflang="id-ID" rel="alternate"/>
# <link href="https://www.kayak.ie/flights/CMN-PAR/2023-12-04" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.il.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="en-IL" rel="alternate"/>
# <link href="https://www.kayak.co.in/flights/CMN-PAR/2023-12-04" hreflang="en-IN" rel="alternate"/>
# <link href="https://www.kayak.it/flights/CMN-PAR/2023-12-04" hreflang="it-IT" rel="alternate"/>
# <link href="https://www.kayak.co.jp/flights/CMN-PAR/2023-12-04" hreflang="ja-JP" rel="alternate"/>
# <link href="https://www.kayak.co.kr/flights/CMN-PAR/2023-12-04" hreflang="ko-KR" rel="alternate"/>
# <link href="https://www.kayak.com.mx/flights/CMN-PAR/2023-12-04" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.kayak.com.my/flights/CMN-PAR/2023-12-04" hreflang="en-MY" rel="alternate"/>
# <link href="https://www.kayak.nl/flights/CMN-PAR/2023-12-04" hreflang="nl-NL" rel="alternate"/>
# <link href="https://www.kayak.no/flights/CMN-PAR/2023-12-04" hreflang="no-NO" rel="alternate"/>
# <link href="https://www.nz.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="en-NZ" rel="alternate"/>
# <link href="https://www.kayak.com.pe/flights/CMN-PAR/2023-12-04" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.kayak.com.ph/flights/CMN-PAR/2023-12-04" hreflang="en-PH" rel="alternate"/>
# <link href="https://www.kayak.pl/flights/CMN-PAR/2023-12-04" hreflang="pl-PL" rel="alternate"/>
# <link href="https://www.kayak.pt/flights/CMN-PAR/2023-12-04" hreflang="pt-PT" rel="alternate"/>
# <link href="https://www.ro.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="ro-RO" rel="alternate"/>
# <link href="https://www.kayak.sa/flights/CMN-PAR/2023-12-04" hreflang="ar-SA" rel="alternate"/>
# <link href="https://www.kayak.se/flights/CMN-PAR/2023-12-04" hreflang="sv-SE" rel="alternate"/>
# <link href="https://www.kayak.sg/flights/CMN-PAR/2023-12-04" hreflang="en-SG" rel="alternate"/>
# <link href="https://www.kayak.co.th/flights/CMN-PAR/2023-12-04" hreflang="th-TH" rel="alternate"/>
# <link href="https://www.kayak.com.tr/flights/CMN-PAR/2023-12-04" hreflang="tr-TR" rel="alternate"/>
# <link href="https://www.tw.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="zh-TW" rel="alternate"/>
# <link href="https://www.ua.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="uk-UA" rel="alternate"/>
# <link href="https://www.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="en-US" rel="alternate"/>
# <link href="https://www.vn.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="vi-VN" rel="alternate"/>
# <link href="https://www.za.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="en-ZA" rel="alternate"/>
# <link href="https://www.kayak.bo/flights/CMN-PAR/2023-12-04" hreflang="es-BO" rel="alternate"/>
# <link href="https://www.kayak.co.cr/flights/CMN-PAR/2023-12-04" hreflang="es-CR" rel="alternate"/>
# <link href="https://www.kayak.com.do/flights/CMN-PAR/2023-12-04" hreflang="es-DO" rel="alternate"/>
# <link href="https://www.kayak.com.ec/flights/CMN-PAR/2023-12-04" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.kayak.cat/flights/CMN-PAR/2023-12-04" hreflang="ca-ES" rel="alternate"/>
# <link href="https://www.kayak.com.gt/flights/CMN-PAR/2023-12-04" hreflang="es-GT" rel="alternate"/>
# <link href="https://www.kayak.com.hn/flights/CMN-PAR/2023-12-04" hreflang="es-HN" rel="alternate"/>
# <link href="https://www.he.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="he-IL" rel="alternate"/>
# <link href="https://www.kayak.com.ni/flights/CMN-PAR/2023-12-04" hreflang="es-NI" rel="alternate"/>
# <link href="https://www.kayak.com.pa/flights/CMN-PAR/2023-12-04" hreflang="es-PA" rel="alternate"/>
# <link href="https://www.kayak.com.pr/flights/CMN-PAR/2023-12-04" hreflang="es-PR" rel="alternate"/>
# <link href="https://www.kayak.com.py/flights/CMN-PAR/2023-12-04" hreflang="es-PY" rel="alternate"/>
# <link href="https://www.kayak.com.sv/flights/CMN-PAR/2023-12-04" hreflang="es-SV" rel="alternate"/>
# <link href="https://www.es.kayak.com/flights/CMN-PAR/2023-12-04" hreflang="es-US" rel="alternate"/>
# <link href="https://www.kayak.com.uy/flights/CMN-PAR/2023-12-04" hreflang="es-UY" rel="alternate"/>
# <link href="android-app://com.kayak.android/http/www.kayak.com/deeplinks/flights?a=kayak&amp;p=" rel="alternate"/>
# <link href="https://www.kayak.ae/flights/CMN-PAR/2023-12-04" rel="canonical"/>
# <script async="" src="//securepubads.g.doubleclick.net/tag/js/gpt.js" type="text/javascript"></script><script src="/res/js/perf.js?v=1163821ffa47697b875725d19c556e00b40f5f2b-14pre-flipped&amp;cluster=5"></script><script type="application/ld+json">
# {
# "@context": "https://schema.org",
# "@type": "Website",
# "name": "KAYAK",
# "url": "https://www.kayak.ae/flights/CMN-PAR/2023-12-04"
# }
# </script>
# <link href="//content.r9cdn.net" rel="preconnect"/> <link href="//content.r9cdn.net" rel="dns-prefetch"/> <link href="//apis.google.com" rel="preconnect"/> <link href="//apis.google.com" rel="dns-prefetch"/> <link href="//www.googletagmanager.com" rel="preconnect"/> <link href="//www.googletagmanager.com" rel="dns-prefetch"/> <link href="//www.google-analytics.com" rel="preconnect"/> <link href="//www.google-analytics.com" rel="dns-prefetch"/> <meta content="af188ca0-1818-47ab-bc00-80a6b93a47d0" name="insight-app-sec-validation"/>
# <title>CMN to PAR, 4/12</title>
# <meta content="Save money on airfare by searching for cheap flights on KAYAK. KAYAK compares flight deals on hundreds of airline tickets sites to find you the best prices." name="description"/>
# <style class="_-styletron_hydrate_"></style>
# <script type="text/javascript">
# var initRumScripts = function(d, s) {
# var js = d.createElement(s),
# sc = d.getElementsByTagName(s)[0];
# js.src="/res/js/perf.js?v=1163821ffa47697b875725d19c556e00b40f5f2b-14pre-flipped&cluster=5";
# sc.parentNode.insertBefore(js, sc);
# }
# </script>
# <script type="text/javascript">
# R9RUMConfig = {"navigationTimingEnabled":true,"fullstoryAssignMinValue":0,"navTimingMinValue":0,"fullstoryAssignMaxValue":-3,"cookieMaxValue":400,"navTimingMaxValue":320,"enableUniqueUrls":false,"resourceTimingEnabled":false,"cookieName":"kykprf"};
# (function(d, s) {initRumScripts(d,s)}(document, "script"));
# </script>
# <style></style></head>
# <body class="keel kl kl-override FlightsSearch react react-st wide a11y-focus-outlines en_AE horizon" id="STRS">
# <div class="Common-Page-StandardPage Base-Search-LandingPage Base-Search-SearchPage Flights-Search-FlightSearchPage cur_aed vm-rp" id="OAqr">
# <div class="Common-Layout-StandardBody withFooter" id="G8hu">
# <a class="skipLink" href="#G8hu-pageContent">Skip to main content</a>
# <div id="c2aI9">
# <div class="Ui-Tracking-DataLayer-container" id="c4DvW"></div>
# <div id="ajaxStyleJamCookiesMessage"></div>
# <div class="Common-Layout-React-StandardHeader-container" id="c81YS"><header class="common-layout-react-HeaderV2 fv-6 fv-6-header--fixed fv-6-header--fixed--desktop fv-6-compactSearch" style="height:80px"><div class="fv-6-header"><div></div><div class="kml-layout mod-full edges-m mobile-edges fv-6-header__container fv-6-navBelowHeader c31EJ"><div class="fv-6-left-section"><div class="fv-6-menu-button"><button aria-expanded="false" aria-label="Navigation menu" class="Button-No-Standard-Style theme-light yWJT yWJT-new-nav-ux"><svg height="20" role="img" viewbox="0 0 200 200" width="20" xmlns="http://www.w3.org/2000/svg"><path d="M20 153.333h160v-17.778H20v17.778zm0-44.444h160V91.111H20v17.778zm0-62.222v17.778h160V46.667H20z"></path></svg></button></div><div class="ui-layout-HeaderMainLogo normal-from-l-size main-logo--mobile"><a aria-label="Go to the KAYAK homepage" class="main-logo__link" href="/" itemprop="https://schema.org/logo"><div class="main-logo__logo has-compact-logo"><span class="logo-image" style="transform:translate3d(0,0,0);vertical-align:middle;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;width:auto;height:auto"><svg fill="none" height="100%" role="img" style="width:inherit;height:inherit;line-height:inherit;color:inherit" viewbox="0 0 125 24" width="100%" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M0 24h23.936V0H0v24zm25.266 0h23.936V0H25.266v24zm49.202 0H50.532V0h23.936v24zm1.33 0h23.936V0H75.798v24zM125 24h-23.936V0H125v24z" fill="#FF690F" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M10.287 11.549V6H7.38v12h2.907v-5.548L13.348 18h3.208l-3.33-6 3.33-6h-3.208l-3.061 5.549zm24.785 4.724L34.552 18h-3.104l3.947-12h3.696l3.93 12h-3.194l-.52-1.727h-4.235zm2.117-6.837l-1.4 4.48h2.8l-1.4-4.48zM63.98 18h-2.906v-5.29L57.144 6h3.463l1.938 3.688L64.447 6h3.409l-3.876 6.71V18zm21.624-1.727L85.084 18h-3.105l3.948-12h3.696l3.93 12h-3.194l-.52-1.727h-4.235zm2.117-6.837l-1.4 4.48h2.8l-1.4-4.48zm23.63 2.113V6h-2.907v12h2.907v-5.548L114.412 18h3.208l-3.33-6 3.33-6h-3.208l-3.061 5.549z" fill="#FAFAFC" fill-rule="evenodd"></path> </svg></span><span class="logo-image-compact" style="transform:translate3d(0,0,0);vertical-align:middle;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;width:auto;height:auto"><svg fill="none" height="100%" role="img" style="width:inherit;height:inherit;line-height:inherit;color:inherit" viewbox="0 0 24 24" width="100%" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M0 24h23.936V0H0v24z" fill="#FF690F" fill-rule="evenodd"></path><path clip-rule="evenodd" d="M10.287 11.549V6H7.38v12h2.907v-5.548L13.348 18h3.208l-3.33-6 3.33-6h-3.208l-3.061 5.549z" fill="#FAFAFC" fill-rule="evenodd"></path> </svg></span></div></a></div></div><div class="lfBz"></div><div class="fv-6-right-section"><div><div class="common-layout-react-HeaderAccountWrapper theme-light account--collapsible"><div class="ui-layout-header-HeaderTripsItem"><div class="trips-drawer-wrapper theme-light"><button aria-label="Open Trips drawer" class="trips-drawer-trigger triggerV2"><span aria-hidden="true" class="drawer-trigger-svg"><span style="transform:translate3d(0,0,0);vertical-align:middle;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;width:32px;height:32px"><svg class="oLv- oLv--mod-saved" fill="inherit" height="100%" style="width:inherit;height:inherit;line-height:inherit;color:inherit" viewbox="0 0 40 40" width="100%" xmlns="http://www.w3.org/2000/svg"><defs><path d="M20.02000005345326,29.59999942779541 C19.555000066757202,29.59999942779541 19.102000057697296,29.44499969482422 18.71400010585785,29.14799976348877 C17.022000074386597,27.817999839782715 15.214000225067139,26.086999893188477 13.15999984741211,23.83899974822998 C10.57699966430664,21.01099967956543 9.258999824523926,18.401999711990356 9.258999824523926,16.089999675750732 C9.258999824523926,14.616999626159668 9.82699966430664,13.221999645233154 10.87399959564209,12.1499 ...
# </div>
# <div class="Ui-Foundation-Mcflysearch-FlightSearchFormDialog-container" id="d5P0"><div aria-hidden="true" class="YSUE YSUE-mod-animate YSUE-mod-layer-default YSUE-mod-position-fixed"><div class="YSUE-background YSUE-mod-variant-default"></div><div class="dDYU-off-screen" role="button" tabindex="0"></div><div aria-modal="true" class="dDYU dDYU-mod-theme-default dDYU-mod-variant-header-search-form-v3 dDYU-mod-padding-none dDYU-mod-position-center dDYU-mod-direction-none dDYU-mod-animate a11y-focus-outlines dDYU-mod-shadow-elevation-one" role="dialog"><div class="dDYU-viewport"><div class="dDYU-content"><div aria-label="Close" class="dDYU-close dDYU-mod-variant-right-corner-inside dDYU-mod-size-default" role="button" tabindex="0"><span style="transform: translate3d(0px, 0px, 0px); vertical-align: middle; -webkit-font-smoothing: antialiased;"><svg class="dDYU-closeIcon dDYU-mod-theme-content" height="100%" role="img" style="width: inherit; height: inherit; line-height: inherit; color: inherit;" viewbox="0 0 200 200" width="100%" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M180 37.918L162.082 20L100 82.208L37.918 20L20 37.918L82.208 100L20 162.082L37.918 180L100 117.792L162.082 180L180 162.082L117.792 100z" fill-rule="evenodd"></path></svg></span></div><div class="dDYU-body"><div class="c1r2d c1r2d-mod-vertical-flights c1r2d-mod-starting-position" id="searchFormDialog" tabindex="-1"><section class="c1r2d-form-section"></section></div></div></div></div></div><div class="dDYU-off-screen" role="button" tabindex="0"></div></div></div>
# <div class="Sub-Header">
# </div>
# <main class="pageContent withDrawer compactSearch new-nav-breakpoints mod-hide-nav-earlier body-rp" id="G8hu-pageContent">
# <div class="SearchPage__ResultsPage" id="OAqr-rp">
# <div class="Ui-Searchforms-Flights-Components-FlightScrollSearchBanner-container" id="v4bU"></div>
# <div class="Base-Results-ResultsPage Flights-Results-FlightResultsPage ResultsVisible PhoenixRising" id="UnFk">
# <nav class="aria-controls rp">
# <a href="#UnFk-leftRail">Go to flights filters</a> <a href="#UnFk-inlineSearch">Edit search form</a> <a href="#UnFk-results-section">Go to flights results section</a></nav>
# <div class="progress-bar-sticky" id="UnFk-progress-bar">
# <div>
# <div class="Common-Results-ProgressBar theme-dark" id="c_5Vc" style="height:3px">
# <div class="bar" id="c_5Vc-bar" style="transform:translateX(0%);-ms-transform:translateX(0%)"></div>
# </div>
# <div aria-live="polite" class="c3kRN-visually-hidden" id="hiddenAlertContainer"></div>
# </div>
# </div>
# <div class="keel-container pageContainer">
# <div class="keel-grid pageGrid">
# <div aria-label="Flight result filters" class="col-left-rail animated" id="UnFk-leftRail" role="form" tabindex="-1">
# <nav class="aria-controls rp">
# <a href="#UnFk-inlineSearch">Edit search form</a> <a href="#UnFk-results-section">Go to flights results section</a></nav>
# <div class="Ui-Flights-Results-Components-FlightLeftRail-container" id="LJMD"><div class="OEdL"><div style="position:relative;top:auto;bottom:auto;padding-top:auto;width:auto;transform:translateY(0px)"><div class="e_0j"><div class="BGqO"><div class="BGqO-prediction-container"><div class="biRz-top-row"><div><div class="biRz-title">Our advice</div><div class="biRz-loading">Loading...</div></div></div></div><div class="c3MR7-price-alert c3MR7-mod-border"><div class="Qxqs Qxqs-mod-full-width-no-header"><div class="Qxqs-trackerWithCheckLabel"><div class="Qxqs-wrapper Qxqs-mod-stretch-width"><label class="AAhf AAhf-mod-display-inline AAhf-mod-toggle-vertical-align-center AAhf-mod-label-placement-start AAhf-mod-theme-default" for="Qxqs-priceAlertToggle" id="Qxqs-priceAlertToggle-label"><div class="AAhf-label"><div class="Qxqs-textAndTooltip" role="button" tabindex="0"><span class="Qxqs-text">Track prices</span></div></div><div class="AAhf-thumb-container"><input aria-checked="false" aria-disabled="false" class="AAhf-toggle-input" id="Qxqs-priceAlertToggle" role="switch" tabindex="0" type="checkbox" value="false"/></div></label></div><label class="Qxqs-checked-label" for="Qxqs-priceAlertToggle">OFF</label></div></div></div></div><div class="e_0j-results-count"><div class="bE-8"><span class="bE-8-filtered">52</span> of <div class="bE-8-total-link bE-8-mod-show-link" role="button" tabindex="0">310 flights</div></div></div><div class="PfeE"><div aria-expanded="true" aria-label="Stops" class="Qk4D" role="region"><div class="Qk4D-filter-head"><div aria-expanded="true" aria-label="Stops" class="Qk4D-filter-title Qk4D-mod-size-medium" role="button" tabindex="0"><div class="Qk4D-title-inner">Stops</div><div aria-disabled="true" aria-label="Reset all values for Stops filter" class="Qk4D-filters-reset Qk4D-hidden Qk4D-inline" role="button" tabindex="-1">Reset</div></div></div><div class="p6Cx"><div class="p6Cx-content"><div class="hYzH hYzH-mod-variant-no-heading" role="presentation"><div class="hYzH-filter-checkbox-outer"><div class="hYzH-filter-checkbox-inner"><span class="PVIO PVIO-mod-checked PVIO-mod-shrunken PVIO-mod-theme-default PVIO-mod-size-small PVIO-mod-variant-ellipsis"><span class="PVIO-input-wrapper"><input aria-checked="true" aria-disabled="false" checked="" class="PVIO-input" id="valueSetFilter-vertical-stops-0" name="valueSetFilter-vertical-stops-0" tabindex="0" type="checkbox" value="true"/><svg aria-hidden="true" class="icon" height="1.25em" role="img" viewbox="0 0 200 200" width="1.25em" xmlns="http://www.w3.org/2000/svg"><path d="M132.639 63.231l-48.974 53.26l-17.569-13.51l-12.191 15.855c22.199 17.07 30.128 26.802 38.284 17.932l55.172-60l-14.722-13.537z"></path></svg></span><label class="PVIO-label" for="valueSetFilter-vertical-stops-0" id="valueSetFilter-vertical-stops-0-label"><div class="hYzH-checkbox-label hYzH-mod-variant-one-line">Direct</div></label></span></div><div aria-label="Only show results for Direct" class="hYzH-only-filter hYzH-mod-font-medium-bold" role="button" tabindex="0">only</div></div><div class="hYzH-price-box"><div aria-disabled="true" aria-hidden="true" aria-label="Only show results for Direct" class="hYzH-price" role="button" tabindex="-1">AED 499</div></div></div><div class="hYzH hYzH-mod-variant-no-heading" role="presentation"><div class="hYzH-filter-checkbox-outer"><div class="hYzH-filter-checkbox-inner"><span class="PVIO PVIO-mod-checked PVIO-mod-shrunken PVIO-mod-theme-default PVIO-mod-size-small PVIO-mod-variant-ellipsis"><span class="PVIO-input-wrapper"><input aria-checked="true" aria-disabled="false" checked="" class="PVIO-input" id="valueSetFilter-vertical-stops-1" name="valueSetFilter-vertical-stops-1" tabindex="0" type="checkbox" value="true"/><svg aria-hidden="true" class="icon" height="1.25em" role="img" viewbox="0 0 200 200" width="1.25em" xmlns="http://www.w3.org/2000/svg"><path d="M132.639 63.231l-48.974 53.26l-17.569-13.51l-12.191 15.855c22.199 17.07 30.128 26.802 38.284 17.932l5 ...
# </div>
# <div class="col-list-body spaced animated" id="UnFk-listCol">
# <div class="listBody streaming-in-progress">
# <div class="Common-Widgets-Loader-AriaLoadMessage" id="UnFk-aria-result-msg">
# <div aria-busy="false" aria-label="" aria-live="polite" aria-relevant="additions text" id="UnFk-aria-result-msg-message" style="font-size:0;height:0;width:0;">
# </div>
# </div>
# <div aria-label="Flight results section" class="listInner" id="UnFk-results-section" tabbable="" tabindex="0">
# <nav class="aria-controls rp">
# <a href="#UnFk-leftRail">Go to flights filters</a> <a href="#UnFk-inlineSearch">Edit search form</a> </nav>
# <div class="belowSearchContainer" id="UnFk-belowSearchForm">
# <div class="warningsContainer dark-style"></div>
# </div>
# <div class="header-wrapper">
# <div id="UnFk-aboveHeader">
# <div class="aboveHeaderContainer no-margin" id="aboveHeaderContainer">
# <div class="Ui-Flights-Results-Components-FlightAboveHeaderContent-container" id="VJ5L"></div>
# </div>
# </div>
# <div class="Ui-Flights-Results-Components-FlightPriceAlertDriveBy-container" id="iheB"></div>
# <div class="resultsListHeader">
# <div class="resultsHeaderContent">
# <div class="Base-Results-ResultsListHeader Flights-Results-FlightResultsListHeader" id="uFiv">
# <div class="Ui-Flights-Results-Components-FlexMatrix-FlexMatrixContainer-container" id="c6-S_"></div>
# <div class="Ui-Flights-Results-Components-FlightResultsSortOptions-container" id="cbVl"><div class="Hv20"><div aria-label="Cheapest" aria-selected="false" class="Hv20-option" role="button" tabindex="0"><div class="Hv20-content" data-content="price_a"><div class="Hv20-title"><span>Cheapest</span></div><div class="Hv20-value"><div><span>AED 406</span> • <span>11h 00m</span></div></div></div></div><div aria-label="Best" aria-selected="true" class="Hv20-option Hv20-mod-state-active" role="button" tabindex="0"><div class="Hv20-content" data-content="bestflight_a"><div class="Hv20-title"><span>Best</span><span class="Hv20-icon" style="transform: translate3d(0px, 0px, 0px); vertical-align: middle; -webkit-font-smoothing: antialiased;"><svg height="100%" role="img" style="width: inherit; height: inherit; line-height: inherit; color: inherit;" viewbox="0 0 200 200" width="100%" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M100 19c-44.187 0-80 35.813-80 80s35.813 80 80 80s80-35.813 80-80s-35.813-80-80-80zm0 145.455c-36.092 0-65.454-29.363-65.454-65.455S63.908 33.545 100 33.545S165.454 62.909 165.454 99S136.092 164.455 100 164.455zm-8.98-72.284h17.96v55.419H91.02V92.171zm0-35.265h17.96v17.96H91.02v-17.96z" fill-rule="evenodd"></path></svg></span></div><div class="Hv20-value"><div><span>AED 499</span> • <span>3h 15m</span></div></div></div></div><div aria-label="Quickest" aria-selected="false" class="Hv20-option" role="button" tabindex="0"><div class="Hv20-content" data-content="duration_a"><div class="Hv20-title"><span>Quickest</span></div><div class="Hv20-value"><div><span>AED 939</span> • <span>2h 50m</span></div></div></div></div><div class="c1wE_"><div aria-label="Other sort" aria-selected="false" class="c1wE_-handle" role="button" tabindex="0"><div class="c1wE_-icon-wrapper"><svg class="c1wE_-icon" height="1.25em" role="img" viewbox="0 0 200 200" width="1.25em" xmlns="http://www.w3.org/2000/svg"><path d="M40 152.5h30v15H40v-15zm0-25h60v-15H40v15zm0-95v15h120v-15H40zm0 55h90v-15H40v15z"></path></svg></div><div class="c1wE_-label"><div class="c1wE_-title">Other sort</div><div class="c1wE_-subtitle"></div></div></div></div><span class="Hv20-tab-indicator" style="width: 178px; left: 211px;"></span></div></div>
# <div class="Ui-Business-core-BusinessTourFlightResultPage-Index-container" id="ZvQv"></div>
# </div>
# </div>
# </div>
# </div>
# <div id="UnFk-aboveResults">
# <div class="aboveResultsContainer" id="aboveResultsContainer">
# <div class="Flights-Results-FlightAboveResultsContent" id="aIa0">
# </div>
# </div>
# </div>
# <div class="Common-Trips-ResultsSavedItems" id="BYyT">
# <div class="savedItemsList" data-toggle="true" id="BYyT-savedItemsList">
# <div class="resultsListCover" id="BYyT-cover">
# <div class="Common-Widgets-Loader-Loader spinner" id="Krxy" style="height: 48px;line-height:48px;width:48px">
# </div>
# </div>
# <div class="list" data-ajax-replace="" id="savedResultsListContainer">
# </div>
# </div>
# </div>
# <div class="resultsContainer">
# <div class="tl" id="UnFk-cover">
# </div>
# <div aria-busy="true" aria-label="Flight search results" class="resultsList" id="UnFk-list" role="main" tabindex="-1">
# <div class="Ui-Flights-Results-Components-ListView-container" id="c9p7t"><div><div class="Fxw9 Fxw9-mod-loading-overlay"><div class="nrc6" data-resultid="03b2710e4f87bde7d1988b6c91e6c1b9"><div class="nrc6-actions-menu-wrapper"><div class="BiV5"><div class="BiV5-action-item"><div class="jzSs" role="button" tabindex="0"><span class="jzSs-shareSVG"><span style="transform: translate3d(0px, 0px, 0px); vertical-align: middle; -webkit-font-smoothing: antialiased; width: 24px; height: 24px;"><svg height="100%" role="img" style="width: inherit; height: inherit; line-height: inherit; color: inherit;" viewbox="0 0 200 200" width="100%" xmlns="http://www.w3.org/2000/svg"><path d="M71.44 73.669L58.16 60.532c35.793-35.408 39.819-43.23 47.417-35.714l36.103 35.714l-13.28 13.137l-19.12-18.835v76.21h-18.8v-76.21L71.44 73.669zm89.6 38.699v46.534H38.8v-46.534H20v46.534c0 10.271 8.417 18.598 18.8 18.598c130.494 0 128.027 2.073 135.637-5.391c7.415-7.273 5.563-10.989 5.563-59.74h-18.96z"></path></svg></span></span></div></div></div></div><div class="yuAt yuAt-pres-rounded" role="group" tabindex="-1"><div class="nrc6-wrapper"><div class="nrc6-inner"><div class="nrc6-content-section" role="button"><div class="btf6"><div class="btf6-labels"><span class="btf6-badge-wrap"><div class="ZGc- ZGc--mod-margin-left-xxsmall ZGc--mod-theme-default ZGc--mod-variant-action ZGc--mod-layout-inline ZGc--mod-padding-default ZGc--mod-size-default ZGc--mod-bold-text ZGc--mod-nowrap" tabindex="0">Best</div></span></div><div class="btf6-save-button-wrapper"><div aria-label="Save" class="izza izza-pres-outline-to-solid-white izza-highlightSaved" role="button" tabindex="0"><span class="izza-content"><span aria-hidden="true" class="izza-heartIconSVG" style="width: 20px; height: 20px;"><span style="transform: translate3d(0px, 0px, 0px); vertical-align: middle; -webkit-font-smoothing: antialiased; width: 32px; height: 32px;"><svg class="oLv- oLv--mod-unsaved" fill="inherit" height="100%" style="width: inherit; height: inherit; line-height: inherit; color: inherit;" viewbox="0 0 40 40" width="100%" xmlns="http://www.w3.org/2000/svg"><defs><path d="M20.02000005345326,29.59999942779541 C19.555000066757202,29.59999942779541 19.102000057697296,29.44499969482422 18.71400010585785,29.14799976348877 C17.022000074386597,27.817999839782715 15.214000225067139,26.086999893188477 13.15999984741211,23.83899974822998 C10.57699966430664,21.01099967956543 9.258999824523926,18.401999711990356 9.258999824523926,16.089999675750732 C9.258999824523926,14.616999626159668 9.82699966430664,13.221999645233154 10.87399959564209,12.149999618530273 C11.906999588012695,11.090999603271484 13.289000034332275,10.470999717712402 14.749000072479248,10.406000137329102 C17.332000017166138,10.289999961853027 19.077000081539154,11.852999687194824 20.02000005345326,13.066999912261963 C20.96200007200241,11.852999687194824 22.705000162124634,10.289999961853027 25.289000034332275,10.406000137329102 C26.761000156402588,10.470999717712402 28.131000518798828,11.090999603271484 29.164000511169434,12.149999618530273 C30.211000442504883,13.221999645233154 30.779000282287598,14.616999626159668 30.779000282287598,16.089999675750732 C30.779000282287598,18.401999711990356 29.461999893188477,21.01099967956543 26.878000259399414,23.83899974822998 C24.825000286102295,26.086999893188477 23.003000020980835,27.830999851226807 21.324000000953674,29.14799976348877 C20.937000036239624,29.457999229431152 20.485000044107437,29.59999942779541 20.02000005345326,29.59999942779541z M15.006999969482422,12.317999839782715 C15.006999969482422,12.317999839782715 14.839000225067139,12.317999839782715 14.839000225067139,12.317999839782715 C12.823999881744385,12.407999515533447 11.184000015258789,14.099999904632568 11.184000015258789,16.089999675750732 C11.184000015258789,17.884999752044678 12.359000205993652,20.106999695301056 14.580999851226807,22.53499960899353 C16.570000171661377,24.704999923706055 18.300999999046326,26.370999813079834 19.9150000 ...
# </div>
# <div class="Ui-Results-Components-SearchFailed-container" id="LMeK"></div>
# <div class="Common-Results-NoResults hidden" id="r9JT">
# <div class="msg">
# <div class="title">No matching results were found</div>
# <p>Either no provider sites serve the locations you specified or no results are available for your chosen dates.</p>
# </div>
# </div>
# </div>
# </div>
# <div class="resultsListFooter clearfix">
# <div class="resultsPaginator">
# <div class="Ui-Flights-Results-Components-FlightPaginator-container" id="clUB"><div class="ULvh"><div class="ULvh-button show-more-button" role="button" tabindex="0">Show more results</div></div></div>
# </div>
# <div class="Ui-Xsell-FlightsFooterXSell-container" id="b6Ti"></div>
# <div class="Flights-Results-FlightResultsFooterAds" id="yyZs">
# <div class="footerAdGroup footerDisplayAd">
# <div class="Common-Kn-Display location-bottom-left" id="PdJi">
# </div>
# </div>
# <div class="footerAdGroup footerDisplayAd">
# <div class="Common-Kn-Display location-bottom" id="wOvp">
# </div>
# </div>
# </div>
# <div class="Ui-Flights-Results-Components-FlightResultsFooterDisclaimers-container" id="KFDk"><div class="OrUx"><div class="OrUx-disclaimer-text"><div class="OrUx-asterisk">*</div><div class="OrUx-false"><span class="OrUx-daybase">Prices are per person and are for e–tickets and include all taxes &amp; fees in AED.<br/>We attempt to get accurate prices and fees; however, <a href="/help/noguarantee">prices and fees are not guaranteed, and may be subject to last minute changes over which we have no control</a>. Finally, some train and bus prices may not include a service fee added by the provider at checkout.</span><span class="OrUx-total">Prices show the total for all passengers including all taxes and fees in AED, and are specifically for e–tickets. <br/>We attempt to get accurate prices and fees; however,<a href="/help/noguarantee">prices and fees are not guaranteed, and may be subject to last minute changes over which we have no control</a>. Finally, some train and bus prices may not include a service fee added by the provider at checkout.</span></div></div></div></div>
# </div>
# <div class="Ui-Flights-Results-Components-FlightAfterClickContainer-container" id="Zloc"></div>
# <div class="Ui-Results-Components-ShareModalWrapper-container" id="Fobt"></div>
# </div>
# <div class="_igK _ian _iai" id="c-ovn">
# <span class="_h-2 _igK _il3" id="c-ovn-target"></span>
# </div>
# </div>
# <div class="col-right-rail animated" id="UnFk-rightRail">
# <div class="Ui-Flights-Results-Components-FlightRightRail-container" id="c1nXg"><div class="OEdL"><div style="position:relative;top:auto;bottom:auto;padding-top:auto;width:auto;transform:translateY(0px)"><div class="ZUgk"><div class="M9dn"><div id="kn-slot-3135360"></div></div><div class="M9dn M9dn-left-align"><div id="kn-slot-4809065"></div></div></div></div></div></div>
# </div>
# </div>
# <div class="Ui-Flights-Results-Components-FlightClickoutDialogHandlerWrapper-container" id="TERh"></div>
# </div>
# <div aria-hidden="true" class="backToTop" id="UnFk-backToTop" role="button" tabindex="-1">
# <span class="dropdownLink">
# Back to top<span class="icon">
# <svg aria-hidden="true" class="common-widgets-chevron" viewbox="0 0 10 10" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#-images-horizon-common-icon-chevron"></use></svg></span>
# </span>
# </div>
# <div class="Common-Kn-KnDisplay" id="Iy3D"></div>
# <div id="FlightResultsDataLayer"></div>
# </div>
# <div class="Ui-Compareto-CompareToTimedOutModalWrapper-container" id="c-Zx9"></div>
# <div class="Ui-Survey-Survey-container" id="c_J1y"></div>
# <div class="Ui-Flights-Results-Components-FlightsResultsSnapshot-container" id="Jr7B"></div>
# <div class="Common-Results-TabUrgency" id="sdkQ" style="display: none;"></div>
# </div>
# </main>
# <div class="react-footer-wrapper" id="hiWt">
# <div class="Common-Layout-React-StandardFooter-container" id="pRry"><div><footer class="react-footer footer--rp withDrawer new-nav-breakpoints compactSearch pres-centered Su1_ Su1_-right-rail-disabled"><div class="kml-layout mod-wide edges-m mobile-edges c31EJ"><div class="react-footer__menu no-site-map"><div class="Su1_-links-section"><div></div></div></div><div class="Su1_-privacy-menu-wrapper"><div class="react-footer-privacy-menu"><span class="react-footer-privacy-menu__copyright">©<!-- -->2023<!-- --> <!-- -->KAYAK</span></div></div><div class="react-footer__page-description"><div class="c5AWd"><p class="c5AWd-paragraph">Search cheap flights with KAYAK. Search for the cheapest airline tickets for all the top <a href="/airlines">airlines</a> around the world and the <a href="/Top-Flight-Routes.tfr.html">top international flight routes</a>. KAYAK searches hundreds of travel sites to help you find cheap airfare and book a flight that suits you best. Since KAYAK searches many plane tickets sites at once, you can find cheap tickets from cheap airlines quickly.</p><p class="c5AWd-paragraph">KAYAK also helps you find the right <a href="/hotels">hotels</a> for your needs.</p><p class="c5AWd-paragraph">Not what you’re looking for? Find thousands of other <a href="/stays">hotels</a>, <a href="/flights">flights</a> and <a href="/cars">car hire</a> with KAYAK.</p></div></div><div class="Su1_-social-links Su1_-social-icons"><div class="react-app-store-sites hide-on-mobile"><a aria-label="Get it on Google Play" class="react-app-store-sites__link" href="https://play.google.com/store/apps/details?id=com.kayak.android" rel="noopener" target="_blank" title="Get it on Google Play"><svg class="react-app-store-sites__icon" fill="none" height="62" role="img" viewbox="0 0 185 62" width="185" xmlns="http://www.w3.org/2000/svg"> <path d="M169.899 0.000154H14.7087C14.143 0.000154 13.5841 0.000153999 13.0198 0.00323399C12.5476 0.00631398 12.0791 0.015246 11.6023 0.0227919C10.5664 0.0349558 9.53296 0.125925 8.51094 0.294909C7.49035 0.467573 6.50173 0.793102 5.57852 1.26049C4.65647 1.73185 3.81398 2.34432 3.08159 3.07568C2.34536 3.80493 1.73164 4.64785 1.26405 5.57201C0.795147 6.49443 0.470018 7.48289 0.299891 8.50324C0.128134 9.52227 0.0357098 10.553 0.0234482 11.5863C0.00910162 12.0585 0.00755897 12.5322 0 13.0045V48.6003C0.00755897 49.0784 0.00910162 49.5417 0.0234482 50.0202C0.0357214 51.0533 0.128145 52.084 0.299891 53.1029C0.469561 54.1238 0.794708 55.1128 1.26405 56.0355C1.73142 56.9568 2.34522 57.7963 3.08159 58.5215C3.8112 59.2561 4.65424 59.869 5.57852 60.3367C6.50173 60.8054 7.49024 61.1328 8.51094 61.3082C9.53313 61.4758 10.5665 61.5668 11.6023 61.5804C12.0789 61.5909 12.5476 61.5969 13.0199 61.5969C13.5841 61.6 14.143 61.6 14.7087 61.6H169.899C170.454 61.6 171.017 61.6 171.571 61.5969C172.041 61.5969 172.524 61.5909 172.994 61.5804C174.027 61.5675 175.059 61.4765 176.079 61.3082C177.103 61.1316 178.095 60.8042 179.023 60.3367C179.946 59.8687 180.788 59.2559 181.517 58.5215C182.252 57.7935 182.867 56.9545 183.34 56.0355C183.806 55.1121 184.128 54.1232 184.295 53.1029C184.467 52.0838 184.563 51.0533 184.581 50.02C184.588 49.5417 184.588 49.0784 184.588 48.6003C184.6 48.0408 184.6 47.4844 184.6 46.9158V14.6859C184.6 14.1218 184.6 13.5624 184.588 13.0045C184.588 12.5322 184.588 12.0585 184.581 11.5862C184.563 10.5528 184.467 9.52225 184.295 8.50309C184.128 7.48343 183.805 6.49516 183.34 5.57217C182.388 3.71961 180.878 2.21164 179.023 1.26033C178.095 0.794094 177.103 0.468651 176.079 0.294755C175.059 0.125053 174.028 0.0340773 172.994 0.0226379C172.524 0.015092 172.041 0.00600599 171.571 0.00307999C171.017 0 170.454 0 169.899 0L169.899 0.000154Z" fill="black"></path> <path d="M13.0274 60.2525C12.5573 60.2525 12.0987 60.2465 11.6324 60.2361C10.6664 60.2235 9.70261 60.1396 8.74901 59.985C7.85983 59.8321 6.99846 59.5477 6.19331 59.1411C5.39551 58.738 4.66786 58.2094 4.03823 57.5756C3.39943 56.9492 2.8676 56.2228 2.4638 55.425C2.0556 54.622 1.773 ...
# </div>
# </div>
# <div id="G8hu-CCPAConsentContainer">
# </div>
# <div class="Common-Errors-ErrorDialog" id="YvmD">
# </div>
# </div>
# <div aria-modal="true" class="Common-Widgets-Dialog-Dialog R9-Overlay a11y-focus-outlines fromBottom animate" data-dialog-owner="" id="zCf1-dialog" role="dialog" tabindex="-1">
# <div class="last-focusable off-screen" id="zCf1-dialog-focusStartBoundary" tabindex="0"></div>
# <div class="modalBackground" id="zCf1-dialog-modal">
# </div>
# <div class="viewport" id="zCf1-dialog-viewport">
# <div class="content" id="zCf1-dialog-content">
# <button aria-label="Close" class="Button-No-Standard-Style close" id="zCf1-dialog-close">
# <svg aria-hidden="true" class="x-icon-x" viewbox="0 0 9.85 9.93" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#-images-horizon-common-icon-x-icon"></use></svg> </button>
# <div class="body" id="zCf1-dialog-body">
# <div class="Common-Results-UnconfirmedAccountWarning _FX _ino" id="zCf1">
# <div class="_igi _iiE _iaj">
# Check your email. </div>
# <div class="_iaR _idj">
# We just emailed you to have you confirm your account. You'll need to do so in order to receive Price Alert updates. </div>
# </div>
# </div>
# </div>
# </div>
# <div class="last-focusable off-screen" id="zCf1-dialog-focusEndBoundary" tabindex="0"></div>
# </div>
# <div aria-modal="true" class="Common-Widgets-Dialog-Dialog R9-Overlay a11y-focus-outlines Common-Trips-MoveEventDialog fromBottom animate" data-dialog-owner="BYyT" id="Qp_s" role="dialog" tabindex="-1">
# <div class="last-focusable off-screen" id="Qp_s-focusStartBoundary" tabindex="0"></div>
# <div class="modalBackground" id="Qp_s-modal">
# </div>
# <div class="viewport" id="Qp_s-viewport">
# <div class="content" id="Qp_s-content">
# <button aria-label="Close" class="Button-No-Standard-Style close" id="Qp_s-close">
# <svg aria-hidden="true" class="x-icon-x" viewbox="0 0 9.85 9.93" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#-images-horizon-common-icon-x-icon"></use></svg> </button>
# <div class="body" id="Qp_s-body">
# <div class="keel-grid keel-form dialogContentGrid" id="Qp_s-dialogContent">
# <div class="col">
# <div class="body" id="Qp_s-contentPlaceholder">
# </div>
# <div class="loader" id="Qp_s-loader">
# <div class="Common-Widgets-Loader-Loader" id="Ue12" style="">
# <span class="dot dot0" style="width:10px;height:10px;"></span><span class="dot dot1" style="width:10px;height:10px;"></span><span class="dot dot2" style="width:10px;height:10px;"></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="last-focusable off-screen" id="Qp_s-focusEndBoundary" tabindex="0"></div>
# </div>
# <div aria-describedby="YvmD-messages" aria-labelledby="YvmD-title" aria-modal="true" class="Common-Widgets-Dialog-Dialog R9-Overlay a11y-focus-outlines Common-Errors-ErrorDialog-Dialog fromTop animate" data-dialog-owner="YvmD" id="YvmD-dialog" role="alertdialog" tabindex="-1">
# <div class="last-focusable off-screen" id="YvmD-dialog-focusStartBoundary" tabindex="0"></div>
# <div class="modalBackground" id="YvmD-dialog-modal">
# </div>
# <div class="viewport" id="YvmD-dialog-viewport">
# <div class="content" id="YvmD-dialog-content">
# <button aria-label="Close" class="Button-No-Standard-Style close" id="YvmD-dialog-close">
# <svg aria-hidden="true" class="x-icon-x" viewbox="0 0 9.85 9.93" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#-images-horizon-common-icon-x-icon"></use></svg> </button>
# <div class="body" id="YvmD-dialog-body">
# <div class="errorContent">
# <div class="errorTitle" id="YvmD-title"></div>
# <ul class="errorMessages" id="YvmD-messages"></ul>
# <button class="Button-Grey-Invert errorDialogCloseButton" id="YvmD-close">OK</button>
# </div>
# </div>
# </div>
# </div>
# <div class="last-focusable off-screen" id="YvmD-dialog-focusEndBoundary" tabindex="0"></div>
# </div>
# <div aria-hidden="true" id="BufferedSVGWrapper" style="height:0;width:0;overflow:hidden">
# <svg xmlns="http://www.w3.org/2000/svg">
# <symbol class="x-icon-x" id="-images-horizon-common-icon-x-icon" viewbox="0 0 9.85 9.93" xmlns="http://www.w3.org/2000/svg">
# <path d="M.71.79l8.43 8.43M9.14.71L.71 9.14" style="fill:none;stroke:currentColor;stroke-miterlimit:10"></path>
# </symbol>
# <symbol class="common-widgets-chevron" id="-images-horizon-common-icon-chevron" viewbox="0 0 10 10" xmlns="http://www.w3.org/2000/svg"><path d="M4.4,7.32a0.84,0.84,0,0,0,1.2,0L9.07,3.85A0.84,0.84,0,0,0,7.88,2.67L5,5.55,2.12,2.67A0.84,0.84,0,0,0,.93,3.85Z" fill="currentColor"></path></symbol>
# <symbol class="x-icon-x" id="-images-horizon-common-icon-x-icon_iae_jIL_iam" viewbox="0 0 9.85 9.93" xmlns="http://www.w3.org/2000/svg">
# <path d="M.71.79l8.43 8.43M9.14.71L.71 9.14" style="fill:none;stroke:currentColor;stroke-miterlimit:10"></path>
# </symbol>
# </svg>
# </div>
# <script id="moveEventDialogContent" type="x-tmpl-mustache">
# <div class="keel-grid contentGrid">
# <div class="col col-header">
# Move this event into </div>
# <div class="col col-body wide">
# <div class="keel-grid bodyGrid">
# <div id="Qp_s-error" class="col col-error">
# </div>
# {{^hasLegs}}
# <div class="col col-event">
# {{#event}}
# {{#link}}
# <a href="{{{link}}}">{{title}}</a>
# {{/link}}
# {{^link}}
# {{title}}
# {{/link}}
# {{/event}}
# </div>
# {{/hasLegs}}
# {{#hasLegs}}
# <div id="Qp_s-legs" class="col col-legs">
# {{#showLegTabs}}
# <ul class="tabs legs">
# <li rel="Qp_s-allLegs" class="selected">
# All legs </li>
# <li rel="Qp_s-oneLeg">
# One leg </li>
# </ul>
# {{/showLegTabs}}
# <div id="Qp_s-allLegs" class="keel-grid tab visible">
# {{#legs}}
# <div class="col">{{title}}</div>
# {{/legs}}
# </div>
# {{#oneLeg}}
# <div id="Qp_s-oneLeg" class="keel-grid tab">
# <div class="col">{{title}}</div>
# </div>
# {{/oneLeg}}
# </div>
# {{/hasLegs}}
# <div id="Qp_s-trips" class="col col-trips">
# <ul class="tabs trips">
# <li rel="Qp_s-upcoming" {{#hasTrips}}class="selected"{{/hasTrips}}>
# Existing trip </li>
# <li rel="Qp_s-new" {{^hasTrips}}class="selected"{{/hasTrips}}>
# New trip </li>
# </ul>
# <div id="Qp_s-upcoming" class="keel-grid tab{{#hasTrips}} visible{{/hasTrips}}">
# {{^hasTrips}}
# <div class="col">You have no other trips to move this event to.</div>
# {{/hasTrips}}
# {{#hasTrips}}
# <div class="col col-label">
# {{#eventIsHotel}}Save this hotel to:{{/eventIsHotel}}
# {{#eventIsFlight}}Save this flight to:{{/eventIsFlight}}
# {{#eventIsCar}}Save this car to:{{/eventIsCar}}
# {{#eventIsUnknown}}Save this event to:{{/eventIsUnknown}}
# </div>
# <div class="col">
# <div id="Qp_s-dropdown" class="Common-Widgets-Dropdown-Dropdown size-m"
# href="javascript:void(0)" >
# <span id="Qp_s-dropdown-status" class="status" role="presentation">
# </span>
# <div class="icon">
# <svg class="common-widgets-chevron " xmlns="http://www.w3.org/2000/svg" viewBox="0 0 10 10" aria-hidden="true"><use xlink:href="#-images-horizon-common-icon-chevron"/></svg> </div>
# <select id="Qp_s-dropdown-select"
# name=""
# title=""
# data-validation='{"type": "required"}'
# >
# </select>
# </div>
# </div>
# {{/hasTrips}}
# </div>
# <div id="Qp_s-new" class="keel-grid tab{{^hasTrips}} visible{{/hasTrips}}">
# <div class="col col-label">Name your new trip:</div>
# <div class="col">
# <input id="Qp_s-tripName" placeholder="Trip name" type="text" name="tripName"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="col col-footer">
# <button id="Qp_s-moveBtn" class="ui-button">Move</button>
# </div>
# </div>
# </script> <script id="moveEventSuccessContent" type="x-tmpl-mustache">
# <div class="keel-grid contentGrid">
# <div class="col col-header">
# Event moved successfully </div>
# <div class="col col-body confirm">
# Go to <a id="Qp_s-tripLink" target="_blank" href="{{{tripUrl}}}">{{newTripName}}<span class="arrow-right"></span></a>
# </div>
# <div class="col col-footer">
# <button id="Qp_s-closeBtn" type="button">Close</button>
# </div>
# </div>
# </script> <script id="moveEventError" type="x-tmpl-mustache">
# <div class="keel-grid contentGrid">
# <div class="col col-header error">
# {{{title}}}
# </div>
# <div class="col col-body">
# <div class="keel-grid">
# <div class="col">{{{message}}}</div>
# </div>
# </div>
# <div class="col col-footer">
# <button id="Qp_s-closeBtn" type="button">Close</button>
# </div>
# </div>
# </script> <script id="saveToTripToast" type="x-tmpl-mustache">
# <span>
# <span class='r9-toast-text'>Saved to <a href="{{{ tripUrl }}}" target="_blank"><strong>{{ tripName }}</strong></a></span>
# <a href='{{{ tripUrl }}}' class='r9-toast-link' target='_blank'>View Trip</a>
# </span>
# </script>
# <script type="text/javascript">
# window.R9 = window.R9 || {};
# ...
# R9.ComponentManager.registerSingleton("common.compareto.v3.ResultPage", function () { return new R9.common.compareto.v3.ResultPage("gwz1", {"presentation":null,"searchId":"VmGiJgSHU7","vertical":"flights"}); });
# R9.ComponentManager.register("c-Zx9", {
# destroy: function() {
# ReactDOM.unmountComponentAtNode(document.getElementById("c-Zx9"));
# }
# });
# R9.ComponentManager.logReactComponent("ui.compareto.CompareToTimedOutModalWrapper", false, "component");
# R9.ComponentManager.register("c_J1y", {
# destroy: function() {
# ReactDOM.unmountComponentAtNode(document.getElementById("c_J1y"));
# }
# });
# R9.ComponentManager.logReactComponent("ui.survey.Survey", false, "component");
# R9.ComponentManager.registerSingleton("common.booking.SearchIdExpirationChecker", function () { return new R9.common.booking.SearchIdExpirationChecker("zNVD", {"presentation":null,"vertical":null,"global":true,"singleton":true,"searchId":"VmGiJgSHU7","checkTimeout":1500000}); });
# R9.ComponentManager.register("Jr7B", {
# destroy: function() {
# ReactDOM.unmountComponentAtNode(document.getElementById("Jr7B"));
# }
# });
# R9.ComponentManager.logReactComponent("ui.flights.results.components.FlightsResultsSnapshot", false, "flights.results.FlightResultsPage");
# R9.ComponentManager.registerSingleton("flights.results.SplitBookingHelper", function () { return new R9.flights.results.SplitBookingHelper("vT1M", {"presentation":null,"vertical":"flights","global":false,"singleton":true}); });
# R9.ComponentManager.registerSingleton("flights.results.FlightPriceAlertsController", function () { return new R9.flights.results.FlightPriceAlertsController("Ls9_", {"presentation":null,"vertical":"flights","global":true,"singleton":true,"anonUser":true,"showUnconfirmedWarning":false,"initialFormData":{"travsen":0,"code":"CMN","travchd":0,"Enonstop":false,"isOneWay":true,"travsinf":0,"cabin":"e","dest":"PAR","depart_date":"4\/12\/2023","travlinf":0,"oneway":"y","desthint":"PAR","numtrav":1,"travyth":0,"shortDepartDate":"Mon, 4 Dec","destlist":"PAR","travadl":1},"showAlertFeedbackMessaging":true,"killWatchlist":true,"priceAlertUiUpdate":false,"alertSavedMessage":"We\'re tracking prices for this search.","alertSavedMessageShort":"We\'re tracking prices for this search.","alertUpdatedMessage":"Alert filters were updated automatically.","alertManageLinkMessage":"Manage Alerts","alertSaveToTripMessage":"Flight saved to","showManageLink":false,"isPriceAlertsAnon":true,"isAccountWatchListEnabled":true,"resendConfirmationEmailUrl":"\/i\/api\/account\/profile\/v1\/resendConfirmationEmail","reactPriceAlertEnabled":true,"priceAlertOnboardingEnabled":true}); });
# R9.ComponentManager.registerSingleton("common.booking.ClickoutController", function () { return new R9.common.booking.ClickoutController("mXcA", {"presentation":null,"vertical":"flights","global":true,"singleton":true}); });
# new R9.common.results.TabUrgency("sdkQ", {"presentation":null,"title":"Book now:","includeCurrentTitle":true,"waitTime":5000});
# new R9.flights.results.FlightResultsPage("UnFk", {
# searchId: "VmGiJgSHU7",
# pollingTimeout: 60000,
# isMultiFare: false,
# msg: {
# preserved_filters_removed: "There were no results that matched your previous filters, so your filters have been reset.",
# preserved_filters_applied: "Your previous filters have been applied",
# footerMessage: "Prices are per person and do not include baggage fees.",
# footerMessageHf: "Prices are per person and do not include baggage fees. Hacker Fare tickets are sold with different airlines and are subject to each airline’s booking terms, including changes to itineraries.",
# updating_results: "Updating results...",
# },
# ariaMsg: {
# resultsLoading: "Please wait, searching for flights",
# resultsReady: "Flight results are ready",
# noResultsFound: "There are no flights available on your chosen dates. Try changing the dates of your search."
# }
# }, {"presentation":null,"visible":true,"urlFilterState":null,"isCrossSellSearch":false,"blurTransition":false,"spinnerTransition":true,"infinite":false,"button":true,"completed":true,"useStickyPriceType":false,"enableResultsPageFullstoryData":true,"logClientTimeoutToKibana":true,"showExpiredResultsMessage":true,"destroyAdsForForbiddenCountries":true,"inlineResultsDisplayAd":true,"idleExpireMinutes":60,"fastCover":true,"placeholderDelay":0,"enforceIdleTimeout":true,"exponentialBackoffDelay":true,"showFilteredButSimilar":false,"secondPhaseTimeout":40000,"secondPhaseWait":2000,"useUrlFilterState":true,"useUrlSortMode":true,"animateInlineSearch":false,"sortMode":"bestflight","ascending":true,"searchId":"VmGiJgSHU7","defaultSortType":"bestflight_a","priceType":"daybase","filteredResultsCount":52,"totalResultsCount":310,"availableResultsCount":0,"filtersData":{"dupcodeshare":{"dynamicTitle":"Show Duplicate Codeshares","isDirty":false,"isFiltering":false,"isUserManipulated":false,"valueMap":{"dupcodeshare":{"rawState":"dupcodeshare;1;;;Show Duplicate Codeshares;1;1;1;0;;1"}},"updateTitle":false,"enabled":true},"alliance":{"dynamicTitle":"Alliance","isDirty":false,"isFiltering":false,"isUserManipulated":false,"valueMap":{"ONE_WORLD":{"rawState":"ONE_WORLD;0;AED\u00A0543;162;oneworld;1;0;0;0"},"SKY_TEAM":{"rawState":"SKY_TEAM;0;AED\u00A01,005;23;SkyTeam;2;0;0;0"},"STAR_ALLIANCE":{"rawState":"STAR_ALLIANCE;0;AED\u00A0574;81;Star Alliance;3;0;0;0"}},"updateTitle":false,"enabled":true},"layoverdur":{"dynamicTitle":"Stopover","leftRange":null,"isDirty":false,"isFiltering":false,"isUserManipulated":false,"maxRange":1405,"rightRange":null,"updateTitle":false,"enabled":true,"minRange":37},"redeye":{"dynamicTitle":"Show red-eyes","isDirty":false,"isFiltering":false,"isUserManipulated":false,"valueMap":{"redeye":{"rawState":"redeye;1;;;Show red-eyes;1;1;1;0;;1"}},"updateTitle":false,"enabled":true},"cabin":{"dynamicTitle":"Cabin","isDirty":false,"isFiltering":false,"isUserManipulated":false,"valueMap":{"":{"rawState":";1;AED\u00A01,374;7;Mixed;4;1;1;0"},"b":{"rawState":"b;1;AED\u00A01,590;33;Business;3;1;1;0"},"e":{"rawState":"e;1;AED\u00A0406;155;Economy;2;1;1;0"},"bfbe":{"rawState":"bfbe;1;AED\u00A0465;164;Basic Economy;1;1;1;0"}},"updateTitle":false,"enabled":true},"virtualinterline":{"dynamicTitle":"Show flights with self-transfers","isDirty":false,"isFiltering":false,"isUserManipulated":false,"valueMap":{"virtualinterline":{"rawState":"virtualinterline;1;;0;Show flights with self-transfers;1;1;1;0;;1"}},"updateTitle":false,"enabled":true},"baditin":{"dynamicTitle":"Show 241 longer flights","isDirty":false,"isFiltering":true,"isUserManipulated":false,"valueMap":{"baditin":{"rawState":"baditin;0;;;Show 241 longer flights;1;1;0;0;;1;;;;;1"}},"updateTitle":false,"enabled":true},"whisky":{"dynamicTitle":"Book on KAYAK","isDirty":false,"isFiltering":false,"isUserManipulated":false,"valueMap":{"whisky":{"rawState":"whisky;0;;;KAYAK options only;1;0;0;0;;1"}},"updateTitle":false,"enabled":true},"split":{"dynamicTitle":"Show Hacker Fares\u00B9","isDirty":false,"isFiltering":false,"isUserManipulated":false,"valueMap":{},"updateTitle":false,"enabled":true},"price":{"dynamicTitle":"Price","leftRange":null,"isDirty":false,"isFiltering":false,"isUserManipulated":false,"maxRange":24204,"rightRange":null,"updateTitle":false,"enabled":true,"minRange":401},"airlines":{"dynamicTitle":"Airlines","isDirty":false,"isFiltering":false,"multisetOptions":{"flylocal":["EY","EK"]},"isUserManipulated":false,"valueMap":{"88":{"rawState":"88;1;;2;AnadoluJet;7;1;1;0;;1"},"TU":{"rawState":"TU;1;AED\u00A0804;10;Tunisair;31;1;1;0"},"W9":{"rawState":"W9;1;;4;Wizz Air UK;37;1;1;0;;1"},"69":{"rawState":"69;1;;7;BlaBlaBus;8;1;1;0;;1"},"VY":{"rawState":"VY;1;AED\u00A02,280;12;Vueling;34;1;1;0"},"BJ":{"rawState":"BJ;1;;1;Nouvelair;20;1;1;0;;1"},"FR":{"rawState":"FR;1;;30;Ryanair;24;1;1;0;;1"},"HV":{"rawState":"HV;1;;7;Transavia;28;1;1;0;;1"},"2C":{"rawState":"2C;1;;27;SNCF;26;1;1 ...
# R9.ComponentManager.registerSingleton("common.kn.BlockerDetector", function () { return new R9.common.kn.BlockerDetector("iuMg", {"presentation":null,"vertical":null,"global":true,"singleton":true,"selfAdsUrl":"\/ads\/dfp\/banner300x250\/ads.js","remoteAdsImgUrl":"\/\/www.google-analytics.com\/collect?intended=1"}); });
# R9.ComponentManager.register("c4DvW", {
# destroy: function() {
# ReactDOM.unmountComponentAtNode(document.getElementById("c4DvW"));
# }
# });
# R9.ComponentManager.logReactComponent("ui.tracking.DataLayer", true, "default");
# new R9.common.privacy.StyleJamHeaderCookiesMessage("f7B2", {
# "gdprEnabled": "false" == "true",
# "dataTransferConsentEnabled": "false" == "true",
# "ajaxComponent": ""
# });
# new R9.common.currency.StyleJamCurrencyMessage("mH85", {
# displayLater: false,
# displayImmediately: false,
# localeCountryCode: "ae"
# });
# R9.ComponentManager.register("c81YS", {
# destroy: function() {
# ReactDOM.unmountComponentAtNode(document.getElementById("c81YS"));
# }
# });
# R9.ComponentManager.logReactComponent("common.layout.react.StandardHeader", true, "component");
# R9.publish("globals.facebookAppId", "163003079204");
# R9.ComponentManager.register("d5P0", {
# destroy: function() {
# ReactDOM.unmountComponentAtNode(document.getElementById("d5P0"));
# }
# });
# R9.ComponentManager.logReactComponent("ui.foundation.mcflysearch.FlightSearchFormDialog", true, "default");
# R9.ComponentManager.register("pRry", {
# destroy: function() {
# ReactDOM.unmountComponentAtNode(document.getElementById("pRry"));
# }
# });
# R9.ComponentManager.logReactComponent("common.layout.react.StandardFooter", true, "component");
# R9.ComponentManager.registerSingleton("common.authentication.PromotedSignup", function () { return new R9.common.authentication.PromotedSignup("FQhB", {"presentation":null,"vertical":null,"global":true,"singleton":true,"isMultiLocaleMandatorySignup":false,"showForcedSignup":false}); });
# new R9.common.errors.ErrorDialog("YvmD", {});
# R9.ajax.execute("common/ccpa/CCPAConsent", {
# allowRobots: false,
# appendTo: "G8hu-CCPAConsentContainer",
# replaceContainer: true
# })
# new R9.common.layout.StandardBody("G8hu", {
# "useReactHeaderV2": true,
# "isResponsivePage": false,
# "allowContentMove": false,
# "isNewNavUXEnabled": true});
# new R9.common.seo.SeoMetaTags("FlIO", {});
# new R9.common.core.FastlyTiming("KDxE", {"presentation":null,"runTest":false});
# new R9.flights.search.FlightSearchPage("OAqr", {
# msg: {
# resultPageTitle: "CMN to PAR, 4/12"
# }
# }, {"presentation":null,"isFD":false,"isRP":true,"analyticsVertical":"flight","pageVertical":"flights","resultsPageComponentsMap":{"cars":{"analyticsVertical":"car","component":"cars\/results\/CarResultsPage"},"hotels":{"analyticsVertical":"hotel","component":"hotels\/results\/HotelResultsPage"},"flights":{"analyticsVertical":"flight","component":"flights\/results\/FlightResultsPage"},"trains":{"analyticsVertical":"train","component":"trains\/results\/TrainResultsPage"}},"lazyLoadRP":false,"addClassDuringTransition":true,"staticViewportMetaTag":"width=980","rpInNewTab":true});
# new R9.common.core.RealUserMeasurementsComponent("c3crG", {"presentation":null,"fullstoryEnabled":false,"fsSidIdentifyEnabled":true,"fsUniqueId":"R-58cLDnTpIQaXR9smdJ6yB"});
# R9.Common.enableConsoleBanner("Want to work with an amazing team, building the best search engine in Travel?", "https:\/\/www.kayak.com\/careers", false);
# R9.Common.enableKonamiCode("");
# new R9.common.core.FullyInvisibleCaptcha("GkRp", {"presentation":null,"enabled":false});
# new R9.common.core.MarketingId("Ru63", {"presentation":null,"suggestedKmkid":"AgmVg4bjFVybgnEVOakKDzg","masterHost":"https:\/\/www.kayak.com","runSyncScript":true});
# } catch (e) { reportError("bufferedScripts", e); }
# try { R9.events.ready("inlineComponents.initialized", "componentsReady"); } catch (e) { reportError("inlineComponents.initialized", e); }
# if (R9.ajax._pendingPriorityRequests <= 0) {
# try { R9.events.ready("ajaxComponent.highPriority.initialized"); } catch (e) { reportError("highPriority.initialized", e); }
# }
# try { R9.Analytics.api.trackPageView(); } catch (e) { reportError("trackPageView", e); }
# });
# window.R9 = window.R9 || {};
# window.R9.init = window.R9.init || [];
# window.R9.init.push(function(event) {
# R9.Social.WebCredentials.tryAutoSignIn();
# });
# window.R9 = window.R9 || {};
# window.R9.init = window.R9.init || [];
# window.R9.init.push(function (event) {
# try {
# new R9.framework.body("Elzj", {"presentation":null,"extraClass":"en_AE react react-st wide a11y-focus-outlines","packageClass":"FlightsSearch","keelClass":"keel","localeClass":"en_AE","focusOutlinesActiveClass":"a11y-tab-navigation"});
# } catch (e) {
# if(window.R9Log) {
# window.R9Log.error.apply(window.R9Log, ["framework", e])
# } else {
# window.console.error.apply(window.console, [e]);
# }
# }
# });
# function runInitWrapper(event) {
# var initComplete = false;
# window.addEventListener("load", function(e){
# if (!initComplete) {
# R9.events.when("page.initialized", function(){
# var load;
# try {
# load = new Event('load');
# } catch (IeDoesntSupportThis) {
# load = document.createEvent('Event');
# load.initEvent('load', false, false);
# }
# window.dispatchEvent(load);
# })
# }
# }, true);
# function runInit() {
# var log = new R9.logger();
# try {
# log.time("init");
# var deferred = document.querySelectorAll("link[data-rel='stylesheet']");
# for (var i = 0; i < deferred.length; i++) {
# var def = deferred[i];
# def.setAttribute('rel','stylesheet');
# def.setAttribute('href', def.getAttribute('data-href'));
# }
# if (R9 && R9.init) {
# for(var i = 0; i < R9.init.length; i++) {
# R9.init[i].call();
# }
# }
# if (R9 && R9.devupdate) {
# R9.devupdate.update();
# }
# initComplete = true;
# } finally {
# log.timeEnd("init");
# }
# try {
# log.time("page.initialized");
# R9.events.ready("page.initialized");
# } finally {
# log.timeEnd("page.initialized");
# }
# }
# setTimeout(runInit, 20);
# }
# document.addEventListener("DOMContentLoaded", runInitWrapper);
# </script>
# <iframe aria-hidden="true" class="ui-tracking-GtmFrame r9GTMFrame r9GTMFrame–unified" id="r9GTMFrame-main" src="/ugtm/flights/CMN-PAR/2023-12-04?sort=bestflight_a" title="gtm"></iframe><div class="r9-tooltip-wrapper cooltip-component-wrapper Color-black no-arrow Animation-slide size-s chrome" id="r9-tooltiprpnotify-wrapper" role="tooltip"><div class="r9-tooltip-container cooltip-component-container Color-black no-arrow Animation-slide size-s chrome" id="r9-tooltiprpnotify-container"></div><div class="r9-tooltip-arrow cooltip-component-arrow Color-black no-arrow Animation-slide size-s chrome" id="r9-tooltiprpnotify-arrow"></div></div><img alt="" src="//www.google-analytics.com/collect?intended=1" style="display: block; width: 0px; height: 0px;"/><img alt="" src="//www.google-analytics.com/collect?intended=1" style="height: 0px; width: 0px; display: block;"/></body></html>

# %%
#get airlines
airlines=[]
items=soup.find_all('div',class_='c5iUd-leg-carrier')
for item in items :
    img=item.find('img')
    alt_text = img.get('alt')
    airlines.append(alt_text)

airlines
# Out:
# ['Transavia France',
#  'BlaBlaBus',
#  'Transavia',
#  'Royal Air Maroc',
#  'Royal Air Maroc',
#  'Royal Air Maroc',
#  'Royal Air Maroc',
#  'Royal Air Maroc',
#  'Air France',
#  'Air France',
#  'Air France',
#  'Air France',
#  'Royal Air Maroc',
#  'Ryanair',
#  'Royal Air Maroc',
#  'easyJet',
#  'Royal Air Maroc',
#  'Ryanair',
#  'Iberia',
#  'TAP Portugal']

# %%
#getduration
durations=[]
duration_div=soup.find_all('div',class_='xdW8 xdW8-mod-full-airport')
for d in duration_div :
    duration=d.find('div',class_='vmXl vmXl-mod-variant-default').text
    durations.append(duration)
durations
# Out:
# ['3h 15m',
#  '11h 00m',
#  '3h 00m',
#  '2h 55m',
#  '2h 55m',
#  '2h 55m',
#  '2h 50m',
#  '3h 15m',
#  '3h 15m',
#  '3h 15m',
#  '3h 10m',
#  '6h 30m',
#  '6h 00m',
#  '5h 20m',
#  '5h 05m',
#  '10h 40m']

# %%
stops=[]
stop_div=soup.find_all('div',class_='vmXl vmXl-mod-variant-default')
for s in stop_div :
    selected_element = s.select_one('.JWEO-stops-text, .JWEO-mod-warning')
    if selected_element:
      stops.append(selected_element.text)
    
stops
# Out:
# ['direct',
#  '1 stop',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  'direct',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop',
#  '1 stop']

# %%
#getprice
prices=[]
price_div=soup.find_all('div',class_='f8F1-price-text-container')

for p in price_div :
    price=p.find('div',class_='f8F1-price-text').text
    price= price.replace('\xa0', ' ')
    prices.append(price)
prices
# Out:
# ['AED 499',
#  'AED 406',
#  'AED 543',
#  'AED 572',
#  'AED 572',
#  'AED 589',
#  'AED 939',
#  'AED 1,005',
#  'AED 1,063',
#  'AED 1,182',
#  'AED 1,237',
#  'AED 673',
#  'AED 800',
#  'AED 894',
#  'AED 1,170',
#  'AED 652']

# %%
#getclass
classes=[]
class_div=soup.find_all('div',class_='aC3z-option')
for c in class_div :
    classe=c.find('div',class_='aC3z-name').text
    classes.append(classe)
classes
# Out:
# ['Economy',
#  'Economy',
#  'Economy',
#  'Economy',
#  'Economy',
#  'Economy',
#  'Economy',
#  'Standard',
#  'Standard',
#  'Standard',
#  'Light',
#  'Value',
#  'Standard',
#  'Value',
#  'Basic',
#  'Discount']

# %%
#get_depature_time
deps=[]
dep_div=soup.find_all('div',class_='vmXl vmXl-mod-variant-large')
for d in dep_div:
    depature=d.find_all('span')
    deps.append(depature[0].text)
#get_arrival_time
arrs=[]
arr_div=soup.find_all('div',class_='vmXl vmXl-mod-variant-large')
for a in arr_div:
    arrival=a.find_all('span')
    arrs.append(arrival[2].text)
print(deps)
print(arrs)
# Out:
# ['19:15', '21:15', '13:25', '18:30', '14:10', '08:10', '12:20', '19:15', '16:35', '08:10', '11:20', '11:05', '17:05', '16:30', '13:35', '12:20']
# ['22:30', '08:15+1', '16:25', '21:25', '17:05', '11:05', '15:10', '22:30', '19:50', '11:25', '14:30', '17:35', '23:05', '21:50', '18:40', '23:00']
